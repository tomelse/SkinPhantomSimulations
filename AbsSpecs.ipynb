# %%
from spectra import blood_mu_a, melanosome_mu_a, water_mu_a, lipid_mu_a
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

matplotlib.rcParams['figure.figsize'] = (2.36,1.97)
matplotlib.rcParams['figure.dpi'] = 200
matplotlib.rcParams.update({'font.size': 8})

# %%
wavelengths = np.linspace(500, 1050, num=60)*1e-9
hb = blood_mu_a(wavelengths, 0, water = False)
hbo2 = blood_mu_a(wavelengths, 1, water = False)
water = water_mu_a(wavelengths)
melanin = melanosome_mu_a(wavelengths, 0.1)
lipid = lipid_mu_a(wavelengths)
lipid_mu_a
# Out:
# <function spectra.lipids.lipid_mu_a(wavelength)>

# %%
plt.semilogy(wavelengths*1e9, hb, label="Hb")
plt.text(900, 100, "Hb", c="C0")
plt.semilogy(wavelengths*1e9, hbo2, label="HbO2")
plt.text(520, 100, "HbO$_2$", c="C1")
plt.semilogy(wavelengths*1e9, melanin, label="Melanin")
plt.text(700, 5000, "Melanin", c="C2")
plt.semilogy(wavelengths*1e9, water, label="Water")
plt.text(750, 10, "Water", c="C3")
plt.semilogy(wavelengths*1e9, lipid, label="Lipids")
plt.text(900, 0.3, "Lipids", c="C4")
plt.xlabel("Wavelength / $nm$")
plt.ylabel(r"$\mu_a$ / $m^{-1}$")
plt.savefig("FiguresOutput/abs_spectra.png", bbox_inches = 'tight',pad_inches = 0)
plt.show()

# %%
! git add --all
! git commit -m "Absorption spectra"
! git push
# Out:
# warning: LF will be replaced by CRLF in AbsSpecs.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in Exp1/Melanin Analysis.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in Exp3/Vessel Depth Analysis.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in Exp4/Vessel Radius Analysis.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in Exp5/SO2 Analysis.ipynb.
# The file will have its original line endings in your working directory
# [master 35be5b8] Absorption spectra
#  34 files changed, 2895 insertions(+), 2733 deletions(-)
#  rewrite AbsSpecs.ipynb (92%)
#  rewrite Exp1/Melanin Analysis.ipynb (87%)
#  rewrite Exp3/Vessel Depth Analysis.ipynb (86%)
#  rewrite Exp4/Vessel Radius Analysis.ipynb (79%)
#  rewrite Exp5/SO2 Analysis.ipynb (86%)
#  rewrite FiguresOutput/abs_spectra.png (98%)
#  rewrite FiguresOutput/depth_SO2.png (99%)
#  rewrite FiguresOutput/depth_SO2_hist.png (98%)
#  rewrite FiguresOutput/depth_THb.png (98%)
#  rewrite FiguresOutput/depth_THb_png.png (99%)
#  rewrite FiguresOutput/depth_abs.png (99%)
#  rewrite FiguresOutput/depth_h2o_map.png (98%)
#  rewrite FiguresOutput/depth_hb_map.png (99%)
#  rewrite FiguresOutput/depth_hbo2_map.png (98%)
#  rewrite FiguresOutput/depth_mel_png.png (98%)
#  rewrite FiguresOutput/depth_so2_map.png (98%)
#  rewrite FiguresOutput/depth_spec.png (99%)
#  rewrite FiguresOutput/depth_top_bottom_spec.png (99%)
#  rewrite FiguresOutput/exponential_decay.png (99%)
#  rewrite FiguresOutput/melanin_THb_box.png (98%)
#  rewrite FiguresOutput/melanin_absorption.png (99%)
#  rewrite FiguresOutput/melanin_absorption_spec.png (99%)
#  rewrite FiguresOutput/melanin_so2_box.png (98%)
#  rewrite FiguresOutput/melanin_so2_hist.png (99%)
#  rewrite FiguresOutput/phantom_layout.png (95%)
#  rewrite FiguresOutput/radius_SO2.png (99%)
#  rewrite FiguresOutput/radius_SO2_hist.png (99%)
#  rewrite FiguresOutput/radius_THb.png (98%)
#  rewrite FiguresOutput/radius_abs_spec.png (99%)
#  rewrite FiguresOutput/so2_THb_box.png (98%)
#  rewrite FiguresOutput/so2_abs_spec.png (99%)
#  rewrite FiguresOutput/so2_energy_box.png (99%)
#  rewrite FiguresOutput/so2_so2_box.png (99%)
#  rewrite FiguresOutput/so2_so2_hist.png (99%)
# To https://github.com/tre26/SkinPhantomSimulations.git
#    5ef4d4b..35be5b8  master -> master
